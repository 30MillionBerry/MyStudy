# %% [markdown]
# <a href="https://colab.research.google.com/github/30MillionBerry/MyStudy/blob/master/Dart_basic_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/* 
main 함수를 기준으로 하여 프로그램이 시작합니다.
문법 끝에는 반드시 ;(세미콜론)을 붙여서 표현합니다.
/커멘트를 위하여 '//', '/* */' 등으로 일반적인 C나 Java 처럼 사용합니다.
변수 선언는 int 나 String 등의 명시 선언 또는 var, dynamic 등으로 동적 선언 방식으로 사용할 수 있습니다.
print 함수를 통하여 콘솔 등에 원하는 문자를 출력가능합니다. 변수명 앞에 $ 을 붙여서 해당 변수 값을 직접 출력 가능합니다.
*/

// void main() {
//   print('Hello World!!!');
// }

// PrintInteger(int number) {
//   print('This is Number $number');
// }

// main() {
//   var number = 42;
//   PrintInteger(number);
// }

// void main() {
//   for (int i = 0; i < 5; i++){
//     print('hello ${i + 1}');
//   }
// }

// void main() {
//   var name = 'Yang HyeonMo';
//   print(name);
  
//   var name2 = 'Lee GyeongYoung';
//   print(name2);
// }

// void main() {
//   // 정수는 integer
//   int number1 = 12;
//   print(number1);
  
//   int number2 = 24;
//   print(number2);
  
//   print(number1 + number2);
//   print(number1 - number2);
//   print(number1 == number2);
//   print(number1 <= number2);
//   print(number1 >= number2);
  
//   double number3 = 2.5;
//   double number4 = 0.5;
//   print(number3 + number4);
//   print(number3 * number4);
//   }

// void main() {
//   bool isTrue = true;
//   bool isFalse = false;
//   print(isFalse);
//   print(isTrue);
// }

// void main() {
//   //글자 타입
//   String name = '양현모';
//   String name2 = '이경영';
  
//   print(name);
//   print(name2);
//   print(name.runtimeType);
//   print(name+'♡'+name2);
//   print('${name}    ${name2}');
//   print('$name $name2');
// }

// void main() {
//   dynamic name = '양현모';
//   print(name);
  
//   var number = 1;
//   print(number);
  
//   print(name.runtimeType);
//   print(number.runtimeType);
  
//   name = 3;
//   number = 2;
  
//   print(name);
// //   print(number) 는 안됌 
// }

// void main() {
//   // null 이 들어갈 수 있는 경우
//   // 그 타입만 들어갈 수 있는 경우
//   String name = '양현모';
//   print(name);
  
//   String? name2 = '이경영';
//   name2 = null;
//   print(name2);
  
//   print(name2!);
// }

// void main() {
//   // final 로 선언하면 변수를 바꿀 수 없다, 빌드타임의 값을 몰라도 된다
//   final String name = '양현모';
//   print(name);
  
//   name = '이경영';
// }

// void main() {
//   // 빌드타임의 값을 모르면 안된다
//   const name2 = '양현모';
//   name2 = '이경영';
// }

// void main() {
//   int number = 2;
//   number ++;
//   print(number);
  
//   number --;
//   print(number);
  
//   double number2 = 4.5;
//   print(number2);
  
//   number2 += 1;
//   print(number2);
  
//   number2 -= 1;
//   print(number2);
// }

// void main() {
//   double? number = 2.0;
//   print(number);
  
//   number = 3;
//   print(number);
  
//   number = null;
//   print(number);
 
//   number ??= 7.0; // number 가 만약에 null 이면 오른쪽 값으로 바꿔라
//   print(number);
// }

// void main() {
//   int number1 = 1;
  
//   print(number1 is int);
//   print(number1 is String);
  
//   print(number1 is! int);
//   print(number1 is! String);
  
// }

// void main() {
//   bool result = 12 > 10 && -2 > 0; // 모든조건이 참이여야
//   print(result);
  
//   bool result2 = 12 > 10 || 1 < 0; // 둘중 하나만 참이면
//   print(result2);
// }

// void main() {
//   // List
//   List<String> names = ['양현모','이경영','신정윤'];
//   List<int> numbers = [1,2,3,4,5,6];
  
//   print(names);
//   print(numbers);

//   print(names[0]);
//   print(numbers[3]);

//   print(names.length);
  
//   names.add('양창은');
//   print(names);
  
//   names.remove('양창은');
//   print(names);
  
//   print(names.indexOf('양현모'));
// }

// void main() {
//   // Map
//   // Key / Valse
//   Map<String, String> dict = {
//     'PM' : '양창은',
//     'Back' : '이경영',
//     'Data' : '양현모',
//   };
//   print(dict);
  
//   Map<String, bool> dict2 = {
//     'PM' : true,
//     'Back' : true,
//     'Data' : false,
//   };
//   print(dict2);
  
//   dict2.addAll({
//     'Cluster' : true,
//   });
//    print(dict2);
  
//    print(dict2['PM']);
   
//    dict2['Front'] = false;
//    print(dict2);
  
//    dict2.remove('PM');
//    print(dict2);
  
//    print(dict2.keys);
//    print(dict2.values);
// }


// void main() {
//   //Set
//   final Set<String> names = {
//     '양',
//     '김',
//     '양',
//     '박',
//   };
//   print(names);
//   print(names.contains('양'));
// }

// void main() {
  
//   int number = 3;
  
//   if (number % 2 == 0){
//     print('짝수 입니다');
//   }else {
//     print('홀수 입니다');
//   }
// }


// void main() {
  
//   int number1 = 2;
    
//   switch(number1 % 3){
//     case 0:
//       print('나머지가 0입니다');
//       break;
      
//     case 1:
//       print('나머지가 1입니다');
//       break;
      
//     default:
//       print('나머지가 2입니다');
//       break;
//   }
// }
